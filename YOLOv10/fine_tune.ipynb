# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO(r"..\models\yolov10m.pt")  # load a pretrained model (recommended for training)

# %%
# Train the model
results = model.train(data=r"..\datasets\coco.yaml", epochs=100, imgsz=640, device="cuda", verbose=True, batch = -1, save = True)
# Out:
# New https://pypi.org/project/ultralytics/8.2.89 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.87  Python-3.11.9 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 4GB Laptop GPU, 4096MiB)
# ...
