# %%
import supervision as sv
from ultralytics import YOLO
import numpy as np

# %%
model = YOLO(r"..\models\yolov10n.pt")
tracker = sv.ByteTrack()
frames_generator = sv.get_video_frames_generator(r"..\videos\vehicle-counting-low.mp4")
start, end = sv.Point(x=0, y=1080), sv.Point(x=3840, y=1080)
line_zone = sv.LineZone(start=start, end=end)

for frame in frames_generator:
    result = model(frame)[0]
    detections = sv.Detections.from_ultralytics(result)
    detections = tracker.update_with_detections(detections)
    crossed_in, crossed_out = line_zone.trigger(detections)
    if np.any(crossed_in) or np.any(crossed_out):
        print("someone crossed")
# Out:
# 0: 384x640 3 cars, 1 bus, 1 truck, 114.0ms
# Speed: 2.0ms preprocess, 114.0ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 8.0ms
# Speed: 4.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 16.0ms
# ...
