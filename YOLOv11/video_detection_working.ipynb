# %%
from ultralytics import YOLOWorld
from ultralytics import YOLO
import supervision as sv
import cv2
import numpy as np

# %%
# !YOLO checks
# Out:
# Ultralytics 8.3.3 🚀 Python-3.11.9 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 4GB Laptop GPU, 4096MiB)
# Setup complete ✅ (16 CPUs, 15.7 GB RAM, 59.7/62.5 GB disk)
#
# OS                  Windows-10-10.0.22631-SP0
# Environment         Windows
# Python              3.11.9
# Install             git
# RAM                 15.68 GB
# CPU                 13th Gen Intel Core(TM) i5-13500H
# CUDA                11.8
#
# numpy               ✅ 1.26.3<2.0.0,>=1.23.0
# matplotlib          ✅ 3.9.2>=3.3.0
# opencv-python       ✅ 4.10.0.84>=4.6.0
# pillow              ✅ 10.2.0>=7.1.2
# pyyaml              ✅ 6.0.2>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.14.1>=1.4.1
# torch               ✅ 2.3.1+cu118>=1.8.0
# torchvision         ✅ 0.18.1+cu118>=0.9.0
# tqdm                ✅ 4.66.5>=4.64.0
# psutil              ✅ 6.0.0
# py-cpuinfo          ✅ 9.0.0
# pandas              ✅ 2.2.2>=1.1.4
# seaborn             ✅ 0.13.2>=0.11.0
# ultralytics-thop    ✅ 2.0.6>=2.0.0
# torch               ✅ 2.3.1+cu118!=2.4.0,>=1.8.0; sys_platform == "win32"

# %%
# Initialize a YOLO-World model
# model = YOLOWorld(r"models\yolov8m-worldv2.pt")  # or select yolov8m/l-world.pt for different size
model = YOLO(r"..\models\yolo11m.pt")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Initialize a YOLO-World model
#       2 # model = YOLOWorld(r"models\yolov8m-worldv2.pt")  # or select yolov8m/l-world.pt for different size
# ----> 3 model = YOLO(r"..\models\yolo11m.pt")
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\engine\model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\engine\model.py:297, in Model._load(self, weights, task)
#     294 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     296 if Path(weights).suffix == ".pt":
# --> 297     self.model, self.ckpt = attempt_load_one_weight(weights)
#     298     self.task = self.model.args["task"]
#     299     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\nn\tasks.py:857, in attempt_load_one_weight(weight, device, inplace, fuse)
#     855 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     856     """Loads a single model weights."""
# --> 857     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     858     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     859     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\nn\tasks.py:784, in torch_safe_load(weight)
#     772 try:
#     773     with temporary_modules(
#     774         modules={
#     775             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#     782         },
#     783     ):
# --> 784         ckpt = torch.load(file, map_location="cpu")
#     786 except ModuleNotFoundError as e:  # e.name is missing module name
#     787     if e.name == "models":
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\utils\patches.py:86, in torch_load(*args, **kwargs)
#      83 if TORCH_1_13 and "weights_only" not in kwargs:
#      84     kwargs["weights_only"] = False
# ---> 86 return _torch_load(*args, **kwargs)
#
# File d:\Major Project\.major_env\Lib\site-packages\torch\serialization.py:1025, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1023             except RuntimeError as e:
#    1024                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1025         return _load(opened_zipfile,
#    1026                      map_location,
#    1027                      pickle_module,
#    1028                      overall_storage=overall_storage,
#    1029                      **pickle_load_args)
#    1030 if mmap:
#    1031     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File d:\Major Project\.major_env\Lib\site-packages\torch\serialization.py:1446, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1444 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1445 unpickler.persistent_load = persistent_load
# -> 1446 result = unpickler.load()
#    1448 torch._utils._validate_loaded_sparse_tensors()
#    1449 torch._C._log_api_usage_metadata(
#    1450     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1451 )
#
# File d:\Major Project\.major_env\Lib\site-packages\torch\serialization.py:1439, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1437         pass
#    1438 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1439 return super().find_class(mod_name, name)
#
# AttributeError: Can't get attribute 'C3k2' on <module 'ultralytics.nn.modules.block' from 'd:\\Major Project\\.major_env\\Lib\\site-packages\\ultralytics\\nn\\modules\\block.py'>

# %%
model.set_classes(['vehicle'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 model.set_classes(['vehicle'])
#
# File d:\Major Project\.major_env\Lib\site-packages\ultralytics\models\yolo\model.py:101, in YOLOWorld.set_classes(self, classes)
#      94 def set_classes(self, classes):
#      95     """
#      96     Set classes.
#      97
#      98     Args:
#      99         classes (List(str)): A list of categories i.e. ["person"].
#     100     """
# --> 101     self.model.set_classes(classes)
#     102     # Remove background if it's given
#     103     background = " "
#
# File d:\Major Project\.major_env\Lib\site-packages\torch\nn\modules\module.py:1709, in Module.__getattr__(self, name)
#    1707     if name in modules:
#    1708         return modules[name]
# -> 1709 raise AttributeError(f"'{type(self).__name__}' object has no attribute '{name}'")
#
# AttributeError: 'DetectionModel' object has no attribute 'set_classes'

# %%
model.to('cuda')  # or 'cpu'
model.device
# Out:
# device(type='cuda', index=0)

# %%
VIDEO = r"videos\vehicle-counting.mp4"

# %%
import cv2

cap = cv2.VideoCapture(VIDEO)

# Get the video's frame width and height
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)

# release the VideoCapture object
cap.release()

# %%
colors = sv.ColorPalette.DEFAULT
video_info = sv.VideoInfo.from_video_path(VIDEO)
video_info
# Out:
# VideoInfo(width=3840, height=2160, fps=25, total_frames=538)

# %%
# extract video frame
generator = sv.get_video_frames_generator(VIDEO)
iterator = iter(generator)

# First fame of the video
frame = next(iterator)

# save first frame
cv2.imwrite(r"images\first_frame_3.png", frame)
# Out:
# True

# %%
polygons = [
  
    np.array([[1198, 868], [1662, 864], [1710, 2092], [46, 2096]]),
    np.array([[1938, 860], [1938, 860], [2310, 840], [3810, 1604], [2454, 1688]])

]

# %%
# initialize our zones

zones = [
    sv.PolygonZone(
        polygon=polygon,
    )
    for polygon in polygons
]

zone_annotators = [
    sv.PolygonZoneAnnotator(
        zone=zone,
        color=colors.by_idx(index),
        thickness=4,
        text_thickness=8,
        text_scale=4
    )
    for index, zone in enumerate(zones)
]

box_annotators = [
    sv.BoxAnnotator(
        color=colors.by_idx(index),
        thickness=4
    )
    for index in range(len(polygons))
]

# %%
def process_frame(frame: np.ndarray, i) -> np.ndarray:

    results = model(frame, imgsz=1280, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)

    for zone, zone_annotator, box_annotator in zip(zones, zone_annotators, box_annotators):
        mask = zone.trigger(detections=detections)
        detections_filtered = detections[mask]
        frame = box_annotator.annotate(scene=frame, detections=detections_filtered)
        frame = zone_annotator.annotate(scene=frame)

    return frame

# %%
results = model(frame, imgsz=1280, verbose=False)[0]
detections = sv.Detections.from_ultralytics(results)

for zone, zone_annotator, box_annotator in zip(zones, zone_annotators, box_annotators):
    mask = zone.trigger(detections=detections)
    detections_filtered = detections[mask]
    frame = box_annotator.annotate(scene=frame, detections=detections_filtered)
    frame = zone_annotator.annotate(scene=frame)

sv.plot_image(frame, (16, 16))

# %%
sv.process_video(source_path=VIDEO, target_path="result_new_yolov10_m.mp4", callback=process_frame)

# %%
def show_video(video_path: str):
    cap = cv2.VideoCapture(video_path)
    frame_index = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Process the frame
        processed_frame = process_frame(frame, frame_index)
        frame_index += 1

        # Create a named window with the ability to resize
        cv2.namedWindow('Processed Video', cv2.WINDOW_NORMAL)


        # Calculate aspect ratio
        aspect_ratio = width / height

        # Set the window size
        cv2.resizeWindow("Processed Video", int(400 * aspect_ratio), 400)

        # Display the processed frame
        cv2.imshow('Processed Video', processed_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
# Call the function to show the video
show_video(r'videos\vehicle-counting.mp4')

# %%
import supervision as sv
import cv2

def show_video_2(video_path: str):
    # Create a VideoCapture object
    cap = cv2.VideoCapture(video_path)
    frame_index = 0

    # Create a video sink to display the processed frames
    video_sink = sv.VideoSink(window_name="Processed Video", window_type=cv2.WINDOW_NORMAL)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Process the frame
        processed_frame = process_frame(frame, frame_index)
        frame_index += 1

        # Get the height and width of the frame
        height, width, _ = processed_frame.shape
        aspect_ratio = width / height

        # Resize the window based on the aspect ratio
        cv2.resizeWindow("Processed Video", int(400 * aspect_ratio), 400)

        # Show the processed frame using supervision's VideoSink
        video_sink(output_frame=processed_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    video_sink.close()

# %%
show_video_2(r'videos\vehicle-counting.mp4')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 show_video_2(r'videos\vehicle-counting.mp4')
#
# Cell In[18], line 10, in show_video_2(video_path)
#       7 frame_index = 0
#       9 # Create a video sink to display the processed frames
# ---> 10 video_sink = sv.VideoSink(window_name="Processed Video", window_type=cv2.WINDOW_NORMAL)
#      12 while cap.isOpened():
#      13     ret, frame = cap.read()
#
# TypeError: VideoSink.__init__() got an unexpected keyword argument 'window_name'

# %%
# Execute inference with the YOLOv8s-world model on the specified image
results = model.predict(r"images\vlcsnap.png")

# Show results
results[0].show()

# %%
# Track with a YOLO-World model on a video
results = model.track(source=r"videos\highway.mp4", stream=True)

# Show results
